# %%
import seaborn as sns 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/Users/julieragsdale/Desktop/covid19/BLT-L/200729_UNC41-A00434_0134_AHNMGMDMXX_abundance_tximport_with_GeneSymbols.csv")

df
# Out:
#                ENSEMBL    SYMBOL  EBP_COVID_16_E840_GCAAGATC_CTTCGACT_S1_L001  \
# 0      ENSG00000000003    TSPAN6                                    24.076270
# 1      ENSG00000000005      TNMD                                     0.206200
# 2      ENSG00000000419      DPM1                                    38.520273
# 3      ENSG00000000457     SCYL3                                     3.944772
# 4      ENSG00000000460  C1orf112                                     1.538811
# ...                ...       ...                                          ...
# 60729  ENSGR0000275287       NaN                                     0.000000
# 60730  ENSGR0000276543       NaN                                     0.000000
# 60731  ENSGR0000277120       NaN                                     0.000000
# 60732  ENSGR0000280767       NaN                                     0.000000
# 60733  ENSGR0000281849       NaN                                     0.000000
#
# ...

# %%
df=df.dropna()

df=df.set_index('SYMBOL')

df
# Out:
#                        ENSEMBL  EBP_COVID_16_E840_GCAAGATC_CTTCGACT_S1_L001  \
# SYMBOL
# TSPAN6         ENSG00000000003                                    24.076270
# TNMD           ENSG00000000005                                     0.206200
# DPM1           ENSG00000000419                                    38.520273
# SCYL3          ENSG00000000457                                     3.944772
# C1orf112       ENSG00000000460                                     1.538811
# ...                        ...                                          ...
# PAX6-AS1       ENSG00000281880                                     0.000000
# PAUPAR         ENSG00000281880                                     0.000000
# GIMAP1-GIMAP5  ENSG00000281887                                     6.140395
# SNORA50A       ENSG00000281910                                     0.000000
# LINC01144      ENSG00000281912                                     0.869342
#
# ...

# %%
df[df['ENSEMBL']=='ENSG00000211899']
# Out:
# Empty DataFrame
# ...

# %%
df.columns
# Out:
# Index(['ENSEMBL', 'EBP_COVID_16_E840_GCAAGATC_CTTCGACT_S1_L001',
#        'EBP_COVID_16_E840_GCAAGATC_CTTCGACT_S1_L002',
#        'EBP_COVID_17_E844_TTCGTTGG_CGTGTGTA_S2_L001',
#        'EBP_COVID_17_E844_TTCGTTGG_CGTGTGTA_S2_L002',
#        'EBP_COVID_18_E862_ATGCCTGT_CGCAATCT_S3_L001',
#        'EBP_COVID_18_E862_ATGCCTGT_CGCAATCT_S3_L002',
#        'EBP_COVID_19_E862_GATCGAGT_AGTTCGTC_S4_L001',
#        'EBP_COVID_19_E862_GATCGAGT_AGTTCGTC_S4_L002',
#        'EBP_COVID_20_E863_AGTGGATC_GTCATCGA_S5_L001',
#        'EBP_COVID_20_E863_AGTGGATC_GTCATCGA_S5_L002',
#        'EBP_COVID_21_E863_CAATGTGG_GTCGAAGA_S6_L001',
#        'EBP_COVID_21_E863_CAATGTGG_GTCGAAGA_S6_L002',
#        'EBP_COVID_22_E128_CCGTAAGA_TGGACTCT_S7_L001',
#        'EBP_COVID_22_E128_CCGTAAGA_TGGACTCT_S7_L002',
#        'EBP_COVID_23_E838_TGGTACAG_ACTCTCGA_S8_L001',
#        'EBP_COVID_23_E838_TGGTACAG_ACTCTCGA_S8_L002',
#        'EBP_COVID_24_F168_GCTATCCT_CACCTGTT_S9_L001',
# ...

# %%
df2=df[['EBP_COVID_28_F285_GATAGGCT_TGTGACTG_S13_L001','EBP_COVID_29_F285_ACTCCATC_CCTTGATC_S14_L001',
       'EBP_COVID_25_F276_AAGCACTG_GTTGACCT_S10_L001','EBP_COVID_31_F289_ATATGCGC_CTGATCGT_S16_L001',
        'EBP_COVID_30_F288_ATCACACG_TACGCTAC_S15_L001','EBP_COVID_24_F168_GCTATCCT_CACCTGTT_S9_L001',
        'EBP_COVID_20_E863_AGTGGATC_GTCATCGA_S5_L001','EBP_COVID_21_E863_CAATGTGG_GTCGAAGA_S6_L001',
        'EBP_COVID_18_E862_ATGCCTGT_CGCAATCT_S3_L001','EBP_COVID_19_E862_GATCGAGT_AGTTCGTC_S4_L001',
        'EBP_COVID_26_F283_CAACACCT_TGGTAGCT_S11_L001','EBP_COVID_27_F283_CGGCTAAT_AGAACGAG_S12_L001'
       ]]

df2
# Out:
#                EBP_COVID_28_F285_GATAGGCT_TGTGACTG_S13_L001  \
# SYMBOL
# TSPAN6                                            22.752020
# TNMD                                               0.444735
# DPM1                                              42.903061
# SCYL3                                              5.165249
# C1orf112                                           2.443923
# ...                                                     ...
# PAX6-AS1                                           0.011514
# PAUPAR                                             0.011514
# GIMAP1-GIMAP5                                     12.247655
# SNORA50A                                           0.000000
# LINC01144                                          0.357260
#
#                EBP_COVID_29_F285_ACTCCATC_CCTTGATC_S14_L001  \
# SYMBOL
# TSPAN6                                            18.490177
# TNMD                                               0.688301
# ...

# %%
print(df2.loc['IGHMBP2'])
# Out:
# EBP_COVID_28_F285_GATAGGCT_TGTGACTG_S13_L001     6.937809
# EBP_COVID_29_F285_ACTCCATC_CCTTGATC_S14_L001     9.770355
# EBP_COVID_25_F276_AAGCACTG_GTTGACCT_S10_L001     5.524285
# EBP_COVID_31_F289_ATATGCGC_CTGATCGT_S16_L001     7.763100
# EBP_COVID_30_F288_ATCACACG_TACGCTAC_S15_L001     7.524989
# EBP_COVID_24_F168_GCTATCCT_CACCTGTT_S9_L001      9.352934
# EBP_COVID_20_E863_AGTGGATC_GTCATCGA_S5_L001     15.087530
# EBP_COVID_21_E863_CAATGTGG_GTCGAAGA_S6_L001     11.066706
# EBP_COVID_18_E862_ATGCCTGT_CGCAATCT_S3_L001     16.575824
# EBP_COVID_19_E862_GATCGAGT_AGTTCGTC_S4_L001     16.252367
# EBP_COVID_26_F283_CAACACCT_TGGTAGCT_S11_L001    12.451385
# EBP_COVID_27_F283_CGGCTAAT_AGAACGAG_S12_L001    14.588963
# Name: IGHMBP2, dtype: float64

# %%
#cytokine_genes_list=['TNF','IL17C','CXCL3','IL27','IL6','CCL5','CCL8','CXCL2','CXCL8','CXCL9','CCL7','CXCL11','CXCL10']

ifn_genes_list=['IFNA16',
                'IFNA1',
                'IFNA2',
                'IFNA4',
                'IFNA5',
                'IFNA6',
                'IFNA7',
                'IFNA8',
                'IFNA21',
                'IFNA10',
                'IFNA13',
                'IFNA17','IFNL1','IFNL2','IFNL3','IFNL4','IFNB1'] #'IL28A', 'IL28B', 'IL29']

df3=df2.loc[ifn_genes_list]

df3
# Out:
#         EBP_COVID_28_F285_GATAGGCT_TGTGACTG_S13_L001  \
# SYMBOL
# IFNA16                                      0.404900
# IFNA1                                       1.052605
# IFNA2                                       1.368535
# IFNA4                                       1.052891
# IFNA5                                       1.261810
# IFNA6                                       0.200516
# IFNA7                                       2.012751
# IFNA8                                       0.883790
# IFNA21                                      1.205940
# IFNA10                                      1.219464
# IFNA13                                      1.032167
# IFNA17                                      1.312516
# IFNL1                                       2.296966
# IFNL2                                       0.204156
# IFNL3                                       0.205279
# IFNL4                                       0.000000
# ...

# %%
col = df3.loc[: , "EBP_COVID_20_E863_AGTGGATC_GTCATCGA_S5_L001":"EBP_COVID_27_F283_CGGCTAAT_AGAACGAG_S12_L001"]

df3['Naive Control']=col.mean(axis=1)

df3

df4=df3.drop(["EBP_COVID_20_E863_AGTGGATC_GTCATCGA_S5_L001",
              "EBP_COVID_21_E863_CAATGTGG_GTCGAAGA_S6_L001",
              "EBP_COVID_18_E862_ATGCCTGT_CGCAATCT_S3_L001",
              "EBP_COVID_19_E862_GATCGAGT_AGTTCGTC_S4_L001",
              "EBP_COVID_26_F283_CAACACCT_TGGTAGCT_S11_L001",
              "EBP_COVID_27_F283_CGGCTAAT_AGAACGAG_S12_L001"],axis=1)

df4
# Out:
#         EBP_COVID_28_F285_GATAGGCT_TGTGACTG_S13_L001  \
# SYMBOL
# IFNA16                                      0.404900
# IFNA1                                       1.052605
# IFNA2                                       1.368535
# IFNA4                                       1.052891
# IFNA5                                       1.261810
# IFNA6                                       0.200516
# IFNA7                                       2.012751
# IFNA8                                       0.883790
# IFNA21                                      1.205940
# IFNA10                                      1.219464
# IFNA13                                      1.032167
# IFNA17                                      1.312516
# IFNL1                                       2.296966
# IFNL2                                       0.204156
# IFNL3                                       0.205279
# IFNL4                                       0.000000
# ...

# %%
col = df4.loc[: , "EBP_COVID_28_F285_GATAGGCT_TGTGACTG_S13_L001":"EBP_COVID_31_F289_ATATGCGC_CTGATCGT_S16_L001"]

df4['2dpi']=col.mean(axis=1)

df4

df5=df4.drop(["EBP_COVID_28_F285_GATAGGCT_TGTGACTG_S13_L001",
              "EBP_COVID_29_F285_ACTCCATC_CCTTGATC_S14_L001",
              "EBP_COVID_25_F276_AAGCACTG_GTTGACCT_S10_L001",
              "EBP_COVID_31_F289_ATATGCGC_CTGATCGT_S16_L001"],axis=1)

df5
# Out:
#         EBP_COVID_30_F288_ATCACACG_TACGCTAC_S15_L001  \
# SYMBOL
# IFNA16                                      0.214568
# IFNA1                                       1.024633
# IFNA2                                       0.456870
# IFNA4                                       0.400145
# IFNA5                                       0.604554
# IFNA6                                       0.072693
# IFNA7                                       0.527917
# IFNA8                                       0.450853
# IFNA21                                      0.375378
# IFNA10                                      0.544662
# IFNA13                                      0.011726
# IFNA17                                      0.481620
# IFNL1                                       1.057818
# IFNL2                                       0.463354
# IFNL3                                       0.286926
# IFNL4                                       0.000000
# ...

# %%
col = df5.loc[: , "EBP_COVID_30_F288_ATCACACG_TACGCTAC_S15_L001":"EBP_COVID_24_F168_GCTATCCT_CACCTGTT_S9_L001"]

df5['6dpi']=col.mean(axis=1)

df5

df6=df5.drop(["EBP_COVID_30_F288_ATCACACG_TACGCTAC_S15_L001","EBP_COVID_24_F168_GCTATCCT_CACCTGTT_S9_L001"],axis=1)

df6
# Out:
#         Naive Control      2dpi      6dpi
# SYMBOL
# IFNA16       0.000000  1.114365  0.128422
# IFNA1        0.021697  3.316202  0.589973
# IFNA2        0.001952  2.238008  0.420562
# IFNA4        0.000000  2.164572  0.256962
# IFNA5        0.016760  2.567545  0.401520
# IFNA6        0.004863  0.381856  0.042157
# IFNA7        0.008075  2.772273  0.361743
# IFNA8        0.005643  1.946846  0.271974
# IFNA21       0.061516  2.264807  0.244564
# IFNA10       0.000000  2.381148  0.292804
# IFNA13       0.000000  1.286794  0.019909
# IFNA17       0.000000  2.245380  0.327024
# IFNL1        0.151792  2.522728  1.111436
# IFNL2        0.004429  0.521667  0.478958
# IFNL3        0.012530  0.409477  0.441912
# IFNL4        0.000000  0.000000  0.000000
# IFNB1        0.014814  3.638620  1.770956

# %%
df8=np.log10(df6)

df8
# Out:
# /Users/julieragsdale/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.
#         Naive Control      2dpi      6dpi
# SYMBOL
# IFNA16           -inf  0.047027 -0.891361
# IFNA1       -1.663590  0.520641 -0.229168
# IFNA2       -2.709631  0.349862 -0.376170
# IFNA4            -inf  0.335372 -0.590132
# IFNA5       -1.775717  0.409518 -0.396293
# IFNA6       -2.313066 -0.418101 -1.375130
# IFNA7       -2.092831  0.442836 -0.441600
# IFNA8       -2.248490  0.289331 -0.565473
# IFNA21      -1.211013  0.355031 -0.611608
# IFNA10           -inf  0.376786 -0.533423
# IFNA13           -inf  0.109509 -1.700961
# IFNA17           -inf  0.351290 -0.485421
# IFNL1       -0.818752  0.401870  0.045885
# IFNL2       -2.353727 -0.282607 -0.319703
# IFNL3       -1.902049 -0.387770 -0.354665
# IFNL4            -inf      -inf      -inf
# IFNB1       -1.829333  0.560937  0.248208

# %%
ifn_df= df8

ifn_df
# Out:
#         Naive Control      2dpi      6dpi
# SYMBOL
# IFNA16           -inf  0.047027 -0.891361
# IFNA1       -1.663590  0.520641 -0.229168
# IFNA2       -2.709631  0.349862 -0.376170
# IFNA4            -inf  0.335372 -0.590132
# IFNA5       -1.775717  0.409518 -0.396293
# IFNA6       -2.313066 -0.418101 -1.375130
# IFNA7       -2.092831  0.442836 -0.441600
# IFNA8       -2.248490  0.289331 -0.565473
# IFNA21      -1.211013  0.355031 -0.611608
# IFNA10           -inf  0.376786 -0.533423
# IFNA13           -inf  0.109509 -1.700961
# IFNA17           -inf  0.351290 -0.485421
# IFNL1       -0.818752  0.401870  0.045885
# IFNL2       -2.353727 -0.282607 -0.319703
# IFNL3       -1.902049 -0.387770 -0.354665
# IFNL4            -inf      -inf      -inf
# IFNB1       -1.829333  0.560937  0.248208

# %%
#IFN JET HEATMAP

fig, ax = plt.subplots(figsize=(7.5,6))
cmap = plt.cm.jet
ax1 = sns.heatmap(ifn_df,cmap=cmap,vmin=-3,vmax=1)#linewidths=.5)
#cbar = ax1.collections[0].colorbar
ax.set_ylim(0, 17)
plt.yticks(rotation='horizontal')


#tick marks for Cytokines
#cbar.set_ticks([-2,-1,0,1,2,3])
#cbar.set_ticklabels(['0.01','0.1','1','10','100','1000'])

ax1.set_title("BLTL Round2 IFN Genes log10TPM")
#plt.savefig("BLTL_Round2_allIFN_Heatmap_logTPM_jet_09_16_20.png")

# %%
#IFN JET HEATMAP

fig, ax = plt.subplots(figsize=(7.5,6))
cmap = plt.cm.jet
ax1 = sns.heatmap(ifn_df,cmap=cmap,vmin=-3,vmax=2,annot=True,fmt='f')#linewidths=.5)
#cbar = ax1.collections[0].colorbar
ax.set_ylim(0, 17)
plt.yticks(rotation='horizontal')


#tick marks for Cytokines
#cbar.set_ticks([-2,-1,0,1,2,3])
#cbar.set_ticklabels(['0.01','0.1','1','10','100','1000'])

ax1.set_title("BLTL Round2 all IFN Genes log10TPM")
plt.savefig("BLTL_Round2_allIFN_Heatmap_logTPM_jet_09_16_20_w_float_values.png")
